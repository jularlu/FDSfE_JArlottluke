# %% [markdown]
# <a href="https://colab.research.google.com/github/jularlu/FDSfE_JArlottluke/blob/main/Copy_of_HW2_Stats_Philly_Parks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW2 : Summary statistics - For GEOG271
#
# **By Emmanuel Chinkaka**
#
# ***University of Delaware***
#
#
# This homework performs strictly an exploratory analysis of the data
#
# Consult the class demo noteboo for more: https://github.com/EmmanuelChinkaka/W24-GEOG271-Geographic-Data-Analysis-/blob/main/NEW_DEMO/Descriptive_Stats.ipynb
#
# **important**
# turn in the notebook by uploading it to your github repository in a folder called HW2. Before you upload the notebook make sure you
# - click above: Runtime -> Restart and run all
#
# this will assure that your notebook has no bugs due to running the cells of code out of order.

# %% [markdown]
# **This assigment explores the Philadephia parks data**

# %%
# Importing package

import pandas as pd
import pylab
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read in the data about the Philly parks**
#
# you can find the data at http://data-phl.opendata.arcgis.com/datasets/d52445160ab14380a673e5849203eb64_0.csv
# **Copy the URL above and use it to load the data**

# %%
# Reading the Phylly's park data from the URL baove
pparks = pd.read_csv("http://data-phl.opendata.arcgis.com/datasets/d52445160ab14380a673e5849203eb64_0.csv")

# %%
# get the info and the statistical description of the dataframe
pparks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   OBJECTID                 508 non-null    int64
#  1   PUBLIC_NAME              508 non-null    object
#  2   PARENT_NAME              508 non-null    object
#  3   NESTED                   508 non-null    object
#  4   OFFICIAL_NAME            285 non-null    object
#  5   LABEL                    507 non-null    object
#  6   ALIAS                    352 non-null    object
#  7   DPP_ASSET_ID             508 non-null    int64
#  8   ADDRESS_911              500 non-null    object
#  9   ZIP_CODE                 508 non-null    int64
#  10  ADDRESS_BRT              427 non-null    object
#  11  ALIAS_ADDRESS            428 non-null    object
#  12  ACREAGE                  508 non-null    float64
#  13  PROPERTY_CLASSIFICATION  508 non-null    object
#  14  PPR_USE                  508 non-null    object
#  15  PPR_PROG_DISTRICT        508 non-null    object
#  16  PPR_OPS_DISTRICT         508 non-null    object
#  17  COUNCIL_DISTRICT         507 non-null    object
#  18  POLICE_DISTRICT          507 non-null    object
#  19  CITY_SCALE_MAPS          508 non-null    object
#  20  LOCAL_SCALE_MAPS         508 non-null    object
#  21  PROGRAM_SITES            508 non-null    object
#  22  COMMENTS                 134 non-null    object
#  23  Shape__Area              508 non-null    float64
#  24  Shape__Length            508 non-null    float64
# dtypes: float64(3), int64(3), object(19)
# memory usage: 99.3+ KB

# %%
# show the shape of the parks file dataframe
pparks.shape
# Out:
# (508, 25)

# %%
# show the column names in the dataframe
pparks.columns
# Out:
# Index(['OBJECTID', 'PUBLIC_NAME', 'PARENT_NAME', 'NESTED', 'OFFICIAL_NAME',
#        'LABEL', 'ALIAS', 'DPP_ASSET_ID', 'ADDRESS_911', 'ZIP_CODE',
#        'ADDRESS_BRT', 'ALIAS_ADDRESS', 'ACREAGE', 'PROPERTY_CLASSIFICATION',
#        'PPR_USE', 'PPR_PROG_DISTRICT', 'PPR_OPS_DISTRICT', 'COUNCIL_DISTRICT',
#        'POLICE_DISTRICT', 'CITY_SCALE_MAPS', 'LOCAL_SCALE_MAPS',
#        'PROGRAM_SITES', 'COMMENTS', 'Shape__Area', 'Shape__Length'],
#       dtype='object')

# %%
# show the beginning of the dataframe (the first 5 rows)
pparks.head()
# Out:
#    OBJECTID                                     PUBLIC_NAME  \
# 0         1  William H (Billy) Markward Memorial Playground
# 1         2                                Schuylkill Banks
# 2         3                           Schuylkill River Park
# 3         4                           Frankford Boat Launch
# 4         5                            Robert A Borski Park
#
#              PARENT_NAME NESTED  \
# 0  Schuylkill River Park      Y
# 1       Schuylkill Banks      N
# 2  Schuylkill River Park      N
# 3  Frankford Boat Launch      N
# 4   Robert A Borski Park      N
#
#                                      OFFICIAL_NAME                  LABEL  \
# 0  William H. (Billy) Markward Memorial Playground               Markward
# 1                                              NaN       Schuylkill Banks
# 2                                              NaN  Schuylkill River Park
# 3                            Frankford Boat Launch       Frankford Launch
# 4                            Robert A. Borski Park                 Borski
#
#                                                ALIAS  DPP_ASSET_ID  \
# 0                      Joseph O'Connor Memorial Pool          1903
# 1                                                NaN          2794
# 2                                                NaN          2992
# 3       PA Fish & Boat;Frankford Arsenal Boat Launch          3090
# 4  Orthodox Street Parcel; Bridesburg Riverfront ...          3091
#
#         ADDRESS_911  ZIP_CODE  ... PPR_PROG_DISTRICT PPR_OPS_DISTRICT  \
# 0    400 S TANEY ST     19146  ...                14              5;7
# 1  2425 CHESTNUT ST     19103  ...             10;14              5;7
# 2    400 S TANEY ST     19146  ...                14             5, 7
# 3    5625 TACONY ST     19137  ...                 6                2
# 4  3101 ORTHODOX ST     19137  ...                 7                2
#
#    COUNCIL_DISTRICT POLICE_DISTRICT CITY_SCALE_MAPS LOCAL_SCALE_MAPS  \
# 0                 2            9;17               Y                Y
# 1               2;5            9;17               Y                Y
# 2                 2               9               Y                Y
# 3                 6              15               Y                Y
# 4                 6              15               Y                Y
#
#   PROGRAM_SITES                                           COMMENTS  \
# 0             Y           Markward site includes the O'Connor Pool
# 1             N    Bill 160113 (4/14/16) -South of South St Bridge
# 2             N                                                NaN
# 3             N                                                NaN
# 4             N  Officially acquired from PAID in 10/2019. Doc ...
#
#      Shape__Area Shape__Length
# 0   25871.441406   1094.402639
# 1  101477.171875   9300.670275
# 2   27216.929688    799.048584
# 3   78515.335938   1585.376114
# 4   72926.187500   1304.901416
#
# [5 rows x 25 columns]

# %%
# show the end of the dataframe (the last 5 rows)
pparks.tail()
# Out:
#      OBJECTID                    PUBLIC_NAME                PARENT_NAME  \
# 503       504      61st and Cobbs Creek Park           Cobbs Creek Park
# 504       505      Lawrence Court Breezeways  Lawrence Court Breezeways
# 505       506                  Fernhill Park              Fernhill Park
# 506       507  School District Area (Gorgas)          Susan Gorgas Park
# 507       508              Susan Gorgas Park          Susan Gorgas Park
#
#     NESTED      OFFICIAL_NAME                 LABEL                    ALIAS  \
# 503      Y                NaN  61st and Cobbs Creek
# 504      N                NaN    Lawrence Breezeway  Lawrence Court Walkways
# 505      N                NaN              Fernhill
# 506      Y                NaN                   NaN                      NaN
# 507      Y  Susan Gorgas Park                Gorgas                      NaN
#
#      DPP_ASSET_ID         ADDRESS_911  ZIP_CODE  ... PPR_PROG_DISTRICT  \
# 503          3481  61ST & COBBS CREEK     19143  ...                12
# 504          3867     335 LAWRENCE CT     19106  ...                15
# 505           833      4600 MORRIS ST     19144  ...                 5
# 506             0                 NaN     19128  ...                 4
# 507           803      6424 RIDGE AVE     19128  ...                 4
#
#     PPR_OPS_DISTRICT  COUNCIL_DISTRICT POLICE_DISTRICT CITY_SCALE_MAPS  \
# 503                8                 3              18               Y
# 504                5                 1               6               N
# 505                4                 8              39               Y
# 506                4                 4               5               N
# 507                4                 4               5               Y
#
#     LOCAL_SCALE_MAPS PROGRAM_SITES  \
# 503                Y             N
# 504                Y             N
# 505                Y             N
# 506                N             N
# 507                Y             N
#
#                                            COMMENTS    Shape__Area  \
# 503                                             NaN   35596.937500
# 504                                             NaN    1945.863281
# 505                                             NaN  294423.921875
# 506  1927 Transferred to SD to manage and maintain.   58382.015625
# 507                                             NaN   87612.011719
#
#     Shape__Length
# 503   1037.395645
# 504    394.259401
# 505   4327.841898
# 506    986.309218
# 507   1246.794516
#
# [5 rows x 25 columns]

# %% [markdown]
# ## meausre the central tendency of the Philly park sizes
# measure the mean and the median and compare them

# %%
meanps = pparks['ACREAGE'].mean()
print("The mean is", meanps)

medianps = pparks['ACREAGE'].median()
print("The median is", medianps)
# Out:
# The mean is 19.95358826312992
# The median is 3.599560195

# %%
# show the mean and median sizes of the dataframe
# are they the same?
### they are not the same
# Printing the mean and median
.....
# Out:
# The Mean is: 19.619205270754357
# The Median is: 3.37914443

# %% [markdown]
# 1. what can you conclude from the values of the mean and median you extracted? (discuss in a text cell below)
#
# 2. What can you say about the distribution of the ACREAGE variable in the data?

# %% [markdown]
# hint: to plot a line over the histogram use pl.axvline(x=myx) and pass to this function the x value corresponding to the mean and to the median (in my example that would be called myx). As a default, this will plot a line that spanns the whole y range

# %% [markdown]
# hint: you can import the plotting package matplotlib.pylab and call pylab functions as
# ```pl.plot()```
# ```pl.axvline()```
# ```pl.xlabel```
#
# or you can create a figure with the first command starting from the pandas dataframe as
# ```ax = pparks["ACREAGE"].hist()```
#
# and then use methods specific of the axis object ```ax```: ```ax.plot()``` ```ax.axvline()``` ```ax.set_xlabel```
#
# most of the commands are the same or have small differences (e.g. ```ax.set_xlabel``` instead of ```pl.xlabel```)

# %%
# visualize a histogram of the park size.
# you can use the method of the ACREAGE column .hist()
# choose an appropriate number of bins with the argument bins=
# overplot on the histogram the mean and the median of the distribution

plt.suptitle("Distribution of parks in Philly")
ax = pparks["ACREAGE"].hist()
#lines for mean and median
ax.axvline(x=meanps, color='red', linestyle='dashed', linewidth=2, label='Mean')
ax.axvline(x=medianps, color='green', linestyle='dashed', linewidth=2, label='Median')



# Set labels and legend
ax.set_xlabel("Acreage in Philly")
ax.set_ylabel("# of Parks")
plt.legend()

# Show the plot
plt.show()

#to get the legend to render pass to axvline the argument label="..." with ... being whatever you want displayed

# %% [markdown]
# 3. Describe what the graph means?
#
# The graph represents a histogram of the 'ACREAGE' column in the csv. sheet, which displays where the size of all the parks in Philly lay in terms of acerage

# %% [markdown]
# ## 4. what is the spread of park sizes?
# calculate the standard deviation of the park sized
#
# Remember to manage the decimal places

# %%
#Calculating the standard deviation of the park sizes
stdps = round(pparks["ACREAGE"].std(),2)
print("The standard deviation of the park sizes is", stdps)
# Out:
# The standard deviation of the park sizes is 111.52

# %% [markdown]
# ### 5. select only a subset of the parks: the pasks smaller than 10 acres
# (you can do it similarly to the way we removed "Unknown" from the criminal arrests data in class: set a condition and use it to index the dataframe)
#
# calculate the mean and median and plot a histogram of the park sized with the mean and median indicated on the plot

# %%
# if you need help with this step do ask me about boolean arrays used as indices
# and slicing of arrays and series! remember we have a slack channel #hw3

smallparks = pparks[pparks['ACREAGE'] < 10]
smallparks.head()
# Out:
#     OBJECTID                                     PUBLIC_NAME  \
# 0          1  William H (Billy) Markward Memorial Playground
# 2          3                           Schuylkill River Park
# 15        16                        Whitby Avenue Playground
# 16        17                          29th and Passyunk Park
# 17        18                           Price Street Play Lot
#
#                PARENT_NAME NESTED  \
# 0    Schuylkill River Park      Y
# 2    Schuylkill River Park      N
# 15        Cobbs Creek Park      Y
# 16  29th and Passyunk Park      N
# 17   Price Street Play Lot      N
#
#                                       OFFICIAL_NAME                  LABEL  \
# 0   William H. (Billy) Markward Memorial Playground               Markward
# 2                                               NaN  Schuylkill River Park
# 15                                              NaN                 Whitby
# 16                                              NaN      29th and Passyunk
# 17                                              NaN               Price St
#
#                             ALIAS  DPP_ASSET_ID           ADDRESS_911  \
# 0   Joseph O'Connor Memorial Pool          1903        400 S TANEY ST
# 2                             NaN          2992        400 S TANEY ST
# 15                                         1372  1300 COBBS CREEK PKY
# 16                                          432   2827 W PASSYUNK AVE
# 17                                          826        185 W PRICE ST
#
#     ZIP_CODE  ... PPR_PROG_DISTRICT PPR_OPS_DISTRICT  COUNCIL_DISTRICT  \
# 0      19146  ...                14              5;7                 2
# 2      19146  ...                14             5, 7                 2
# 15     19143  ...                13                8                 3
# 16     19145  ...                14                7                 2
# 17     19144  ...                 4                4                 8
#
#    POLICE_DISTRICT CITY_SCALE_MAPS LOCAL_SCALE_MAPS PROGRAM_SITES  \
# 0             9;17               Y                Y             Y
# 2                9               Y                Y             N
# 15              12               Y                Y             N
# 16               1               Y                Y             N
# 17              14               Y                Y             N
#
#                                     COMMENTS   Shape__Area Shape__Length
# 0   Markward site includes the O'Connor Pool  25871.441406   1094.402639
# 2                                        NaN  27216.929688    799.048584
# 15                                       NaN  38916.484375    949.498194
# 16                                       NaN   3830.242188    247.032048
# 17                                       NaN   1249.839844    143.734003
#
# [5 rows x 25 columns]

# %%
#calculate the mean and median of the parks with size less than 10 acres
mean_smallparks = round(smallparks['ACREAGE'].mean(),3)
median_smallparks =round(smallparks['ACREAGE'].median(),3)

print("The median and mean is", median_smallparks, mean_smallparks)
# Out:
# The median and mean is 2.167 2.941

# %%
#Plot a histogram of the parks with size less than 10 acres with the mean and median indicated on the plot

#intialize plt and fig with title

fig = plt.figure()
ax =smallparks['ACREAGE'].hist()

#plot lines mean and median(i did dashed for easy of seeing it)
ax.axvline(x=mean_smallparks,color = 'red',linestyle='dashed',linewidth=2, label='Mean')
ax.axvline(x=median_smallparks,color ='green',linestyle='dashed',linewidth=2, label='Median')

ax.set_xlabel("Acreage in Philly")
ax.set_ylabel("# of Parks")

plt.suptitle('Histogram showing parks with >10 acres in Philly')

#show legend and show plot
plt.legend()
plt.show()

# %% [markdown]
# 6. Imagine that the reader has no access to my instructions, or to the code. What does this figure show? what should the reader note about the figure?

# %% [markdown]
# **The figure shows a histogram of park sizes for a subset of parks with sizes smaller than 10 acres. which is the most imporant feature of this graph.**

# %% [markdown]
# The parks listed in each row are in some cases subsets of larger parks. The "parent" park is listed under PARENT_NAME.
#
# The challenge is to visualize the distribution of sizes of the  parent parks. To do that you have to aggregate the parks based on the "PARENT_NAME" value and sum the size of the parks. The methods of the dataframe you want to use are
# ```.groupby()```
# and
# ```.sum()```

# %%
# Grouping the Parks based on the parent name
group_park = pparks.groupby(['PARENT_NAME']).sum()
group_park
# Out:
# <ipython-input-49-4bab9352551a>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_park = pparks.groupby(['PARENT_NAME']).sum()
#                                    OBJECTID  DPP_ASSET_ID  ZIP_CODE  \
# PARENT_NAME
# 10th and Lemon Playground                36          2914     19123
# 11th and Cecil B Moore Playground       176          1135     19122
# 12th and Cambria Playground             254          1800     19133
# 18th and Jackson War Memorial           373          1215     19145
# 22nd and Catharine Park                 374          1222     19146
# ...                                     ...           ...       ...
# Womrath Park                            256           120     19124
# Wooden Bridge Run                        71          1632     19114
# Woodside Park                           243          1840     19131
# Woodward Pines                          294          2823     19118
# Yorktown Commons                       2775         20997    114732
#
#                                      ACREAGE    Shape__Area  Shape__Length
# PARENT_NAME
# 10th and Lemon Playground           0.218885    1509.675781     169.494221
# 11th and Cecil B Moore Playground   5.181666   35754.375000     755.891229
# 12th and Cambria Playground         2.337374   16136.882812     542.995987
# 18th and Jackson War Memorial       0.083383     574.429688     148.363162
# 22nd and Catharine Park             0.046244     318.761719      78.402701
# ...                                      ...            ...            ...
# Womrath Park                        2.167680   14970.460938     591.724807
# Wooden Bridge Run                  49.095667  339623.484375    4653.000056
# Woodside Park                       2.619728   18088.925781     615.286813
# Woodward Pines                      1.354531    9370.800781     755.404286
# Yorktown Commons                    0.776328    5356.140625     880.120482
#
# [388 rows x 6 columns]

# %% [markdown]
# 7 Using **sns.pairplot** plot the pairplot of ACREAGE	and Shape__Area variables. What is the relationship that you can see?
#
# **makes a table of only these two variables**

# %%
# Plotting pairplot

pair = group_park[['ACREAGE','Shape__Area']]
pair
# Out:
#                                      ACREAGE    Shape__Area
# PARENT_NAME
# 10th and Lemon Playground           0.218885    1509.675781
# 11th and Cecil B Moore Playground   5.181666   35754.375000
# 12th and Cambria Playground         2.337374   16136.882812
# 18th and Jackson War Memorial       0.083383     574.429688
# 22nd and Catharine Park             0.046244     318.761719
# ...                                      ...            ...
# Womrath Park                        2.167680   14970.460938
# Wooden Bridge Run                  49.095667  339623.484375
# Woodside Park                       2.619728   18088.925781
# Woodward Pines                      1.354531    9370.800781
# Yorktown Commons                    0.776328    5356.140625
#
# [388 rows x 2 columns]

# %%
sns.pairplot(pair,height=2.0)
#gave me a werid error saying SIZE was renamned to HEIGHT i think it has something to do with the version of seaborne

# %%
#Visualize the distribution of the parks grouped by parent name
# Calculate mean and median
groupmean = group_park['ACREAGE'].mean()
groupmedian = group_park['ACREAGE'].median()
print('The Mean of the grouped Parks is:', groupmean)
print('The Median of the grouped Parks is:', groupmedian)
# Out:
# The Mean of the grouped Parks is: 26.124801128015463
# The Median of the grouped Parks is: 3.03529379

# %% [markdown]
# 8. Visualize the distribution of the parks grouped by parent name

# %%
#Visualize the distribution of the parks grouped by parent name

ax =group_park['ACREAGE'].hist()

ax.axvline(groupmean, color='red', linestyle='solid', linewidth=1.5, alpha = .8)
ax.axvline(groupmedian, color='green', linestyle='solid', linewidth=1.5, alpha = .8)

ax.set_xlabel('Park size in acres')
ax.set_ylabel('Number of parks')

ax.legend([groupmean, groupmedian], labels = ['mean', 'median'])

pylab.title("parks grouped by parent");
# Out:
# <ipython-input-86-2b775177d29e>:11: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend([groupmean, groupmedian], labels = ['mean', 'median'])

# %% [markdown]
# 9. Explain what the graph means
#
# **This histogram shows the distribution of the parks listed by parent name which is an identiy in the data frame**

# %% [markdown]
# 10. What could you measure about this new dataset obtained by grouping the data by PARENT_NAME that would allow you to investigate further the difference in the two dataset?
#
# **Mean,median the groupsize associated with the parent name**

# %%
# Measuring the standard deviation of the group parks

group_std = group_park['ACREAGE'].std()

print ("The standard deviation of the grouped data set is", group_std)
# Out:
# The standard deviation of the grouped data set is 151.4251877288923

# %% [markdown]
# 11. Explain what this standard deviation value of 150 means.
#
# the 150 means it is very far away from the mean value given earlier,which means its not a good statistic with it being so far away.

# %% [markdown]
# **END OF HOMEWORK 2**
